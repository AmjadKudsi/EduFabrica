# %% [markdown]
# # IPL Project

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('IPL 2008_17.csv')
df.sample()
# Out:
#      sno  season    city      date team1 team2 toss_winner toss_decision  \
# 235  236    2011  Mumbai  16/05/11    PW    DC          DC         field
#
#      result dl_applied winner  win_by_runs  win_by_wickets Man_of_Match  \
# 235  normal          N     DC            0               6     A Mishra
#
#                           venue F_umpire     S_Umpire  Unnamed: 17
# 235  Dr DY Patil Sports Academy   S Ravi  SK Tarapore          NaN

# %%
df.columns
# Out:
# Index(['sno', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'Man_of_Match', 'venue', 'F_umpire', 'S_Umpire',
#        'Unnamed: 17'],
#       dtype='object')

# %%
del df['Unnamed: 17']

# %% [markdown]
# ### how many seasons data we have ?

# %%
df.season.unique().size
# Out:
# 10

# %% [markdown]
# ### how many teams participated in last 10 years ?

# %%
df.team1.unique().size, df.team2.unique().size
# Out:
# (13, 13)

# %%
df.season.values[:2]
# Out:
# array([2008, 2008])

# %% [markdown]
# ### in how many maatches dl was applied

# %%
df[df['dl_applied'] == 'Y']
# Out:
#      sno  season           city       date team1 team2 toss_winner  \
# 40    41    2008          Delhi   17/05/08    DD  KXIP          DD
# 43    44    2008        Kolkata   18/05/08   KKR   CSK         KKR
# 60    61    2009      Cape Town   19/04/09  KXIP    DD          DD
# 63    64    2009         Durban   21/04/09  KXIP   KKR         KKR
# 89    90    2009      Centurion   7/5/2009   CSK  KXIP         CSK
# 231  232    2011      Bangalore   14/05/11   KKR   RCB         RCB
# 429  430    2014          Delhi  10/5/2014    DD    SH          SH
# 508  509    2015      Hyderabad   15/05/15    SH   RCB          SH
# 538  539    2016      Hyderabad   26/04/16    SH   RPS         RPS
# 561  562    2016        Kolkata   14/05/16   RPS   KKR         RPS
# 565  566    2016  Visakhapatnam   17/05/16    DD   RPS         RPS
# 566  567    2016      Bangalore   18/05/16   RCB  KXIP        KXIP
# 633  634    2017      Bangalore   17/05/17    SH   KKR         KKR
#
# ...

# %%
np.where(df.dl_applied =='Y')
# Out:
# (array([ 40,  43,  60,  63,  89, 231, 429, 508, 538, 561, 565, 566, 633]),)

# %% [markdown]
# ### which team has been the most successfull team in 10 yrs ?

# %%
df.sample()
# Out:
#      sno  season       city      date team1 team2 toss_winner toss_decision  \
# 106  107    2009  Centurion  18/05/09   CSK   KKR         CSK           bat
#
#      result dl_applied winner  win_by_runs  win_by_wickets Man_of_Match  \
# 106  normal          N    KKR            0               7     BJ Hodge
#
#                venue    F_umpire   S_Umpire
# 106  SuperSport Park  SJA Taufel  RB Tiffin

# %%
df.winner.value_counts()
# Out:
# MI      92
# CSK     79
# KKR     77
# RCB     73
# KXIP    70
# RR      63
# DD      62
# SH      42
# DC      29
# RPS     15
# GL      13
# PW      12
# KTK      6
# Name: winner, dtype: int64

# %%
df.winner.unique()
# Out:
# array(['KKR', 'CSK', 'DD', 'RCB', 'RR', 'KXIP', 'DC', 'MI', 'PW', 'KTK',
#        nan, 'SH', 'RPS', 'GL'], dtype=object)

# %%
df.Man_of_Match.value_counts()[:8]
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# G Gambhir         13
# MS Dhoni          13
# Name: Man_of_Match, dtype: int64

# %%
sns.countplot(df.Man_of_Match.value_counts()[:8], data = df)
# Out:
# /Users/sumitkumarshukla/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Man_of_Match', ylabel='count'>

# %%
df = sns.load_dataset('iris')
df.sample()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 48           5.3          3.7           1.5          0.2  setosa

# %%
df.species.value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
df.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, hue = 'species')
plt.savefig('iris_pairplot.jpg')

# %% [markdown]
# ### regression line in the graph

# %%
plt.figure(figsize=(40,40))
sns.lmplot(x = 'petal_length', y = 'sepal_width', hue = 'species', data = df)

# %%
plt.figure(figsize=(40,40))
sns.regplot(x = 'petal_length', y = 'sepal_width', data = df)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>

# %%
iris = sns.load_dataset('iris')

# %%
X = iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = iris['species']

# %%
X.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2

# %%
y.head(2)
# Out:
# 0    setosa
# 1    setosa
# Name: species, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
ir_model = LogisticRegression()
ir_model.fit(X,y)
# Out:
# /Users/sumitkumarshukla/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
predictions = ir_model.predict(X)

# %%
classification_report(y,predictions)
# Out:
# '              precision    recall  f1-score   support\n\n      setosa       1.00      1.00      1.00        50\n  versicolor       0.98      0.94      0.96        50\n   virginica       0.94      0.98      0.96        50\n\n    accuracy                           0.97       150\n   macro avg       0.97      0.97      0.97       150\nweighted avg       0.97      0.97      0.97       150\n'

# %%
np.round(accuracy_score(y, predictions)*100,1)
# Out:
# 97.3

# %%
ir_model.predict([[9.4,4.6,5.0,1.5]])
# Out:
# array(['versicolor'], dtype=object)

# %%
iris.sepal_length.values.max()
# Out:
# 7.9
